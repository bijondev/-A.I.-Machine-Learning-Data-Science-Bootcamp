# %% [markdown]
# <a href="https://colab.research.google.com/github/bijondev/-A.I.-Machine-Learning-Data-Science-Bootcamp/blob/main/pandas_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: install pandas

# !pip install pandas

# %%
# prompt: install matpilotlib

# !pip install matplotlib

# %%
# prompt: read csv

import pandas as pd


df = pd.read_csv('/content/drive/MyDrive/data_science/heart-disease.csv')

df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
import matplotlib.pyplot as plt
df.target.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
df.age.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
from IPython.display import Image

Image(filename='/content/drive/MyDrive/data_science/6-step-ml-framework.png', width=600)

# %%
ls
# Out:
# drive/  sample_data/

# %%
# !ls
# Out:
# drive  sample_data
