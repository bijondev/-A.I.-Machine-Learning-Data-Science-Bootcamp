# %% [markdown]
# <a href="https://colab.research.google.com/github/bijondev/-A.I.-Machine-Learning-Data-Science-Bootcamp/blob/main/Pandas_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install numpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
car_sales = pd.read_csv("/content/drive/MyDrive/data_science/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
carsales.to_csv("export-car-sales.csv")

# %%
export_car_sales = pd.read_csv("export-car-sales.csv")
export_car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
heart_disease = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# # Describe data

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# <ipython-input-19-04f02239622f>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   car_sales.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_price = pd.Series([3000, 15000, 8000, 92500])
car_price.mean()
# Out:
# 29625.0

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
car_sales["Odometer (KM)"].sum()
# Out:
# 786014

# %% [markdown]
# # Viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# # .loc & .iloc

# %%
animals = pd.Series(["Cat", "Dog", "Fox", "Snake", "Lion"], index=[0,2,5,4,2])
animals
# Out:
# 0      Cat
# 2      Dog
# 5      Fox
# 4    Snake
# 2     Lion
# dtype: object

# %%
animals.loc[2]
# Out:
# 2     Dog
# 2    Lion
# dtype: object

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
animals.iloc[3]
# Out:
# 'Snake'

# %%
animals.iloc[:3]
# Out:
# 0    Cat
# 2    Dog
# 5    Fox
# dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales.Colour
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales[(car_sales["Make"]=="Toyota") & (car_sales["Odometer (KM)"] > 100000)]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean()
# Out:
# <ipython-input-58-b0a0096139ad>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   car_sales.groupby(["Make"]).mean()
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Doors"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"] = car_sales["Price"].replace('[\$,]', '', regex=True).astype(float).astype(int)
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
car_sales["Price"].hist()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Price"].hist()
# Out:
# <Axes: >

# %%
car_sales["Make"]=car_sales["Make"].str.lower()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
missing_data = pd.read_csv("/content/drive/MyDrive/data_science/missing-data-car-sales.csv")
missing_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White       150043.0    4.0   $4,000.00
# 1   Honda    Red        87899.0    4.0   $5,000.00
# 2  Toyota   Blue        32549.0    NaN   $7,000.00
# 3     BMW  Black        11179.0    5.0  $22,000.00
# 4  Nissan  White            NaN    4.0   $3,500.00
# 5  Toyota  Green        99213.0    4.0   $4,500.00
# 6   Honda   Blue        45698.0    4.0         NaN
# 7   Honda   Blue        54738.0    4.0   $7,000.00
# 8  Toyota    NaN        60000.0    4.0   $6,250.00
# 9  Nissan  White        31600.0    4.0   $9,700.00

# %%
missing_data["Odometer (KM)"].fillna(missing_data["Odometer (KM)"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     32549.000000
# 3     11179.000000
# 4     63657.666667
# 5     99213.000000
# 6     45698.000000
# 7     54738.000000
# 8     60000.000000
# 9     31600.000000
# Name: Odometer (KM), dtype: float64

# %%
missing_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White       150043.0    4.0   $4,000.00
# 1   Honda    Red        87899.0    4.0   $5,000.00
# 2  Toyota   Blue        32549.0    NaN   $7,000.00
# 3     BMW  Black        11179.0    5.0  $22,000.00
# 4  Nissan  White            NaN    4.0   $3,500.00
# 5  Toyota  Green        99213.0    4.0   $4,500.00
# 6   Honda   Blue        45698.0    4.0         NaN
# 7   Honda   Blue        54738.0    4.0   $7,000.00
# 8  Toyota    NaN        60000.0    4.0   $6,250.00
# 9  Nissan  White        31600.0    4.0   $9,700.00

# %%
missing_data["Odometer (KM)"].fillna(missing_data["Odometer (KM)"].mean(), inplace=True)

# %%
missing_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White  150043.000000    4.0   $4,000.00
# 1   Honda    Red   87899.000000    4.0   $5,000.00
# 2  Toyota   Blue   32549.000000    NaN   $7,000.00
# 3     BMW  Black   11179.000000    5.0  $22,000.00
# 4  Nissan  White   63657.666667    4.0   $3,500.00
# 5  Toyota  Green   99213.000000    4.0   $4,500.00
# 6   Honda   Blue   45698.000000    4.0         NaN
# 7   Honda   Blue   54738.000000    4.0   $7,000.00
# 8  Toyota    NaN   60000.000000    4.0   $6,250.00
# 9  Nissan  White   31600.000000    4.0   $9,700.00

# %%
missing_data.dropna()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White  150043.000000    4.0   $4,000.00
# 1   Honda    Red   87899.000000    4.0   $5,000.00
# 3     BMW  Black   11179.000000    5.0  $22,000.00
# 4  Nissan  White   63657.666667    4.0   $3,500.00
# 5  Toyota  Green   99213.000000    4.0   $4,500.00
# 7   Honda   Blue   54738.000000    4.0   $7,000.00
# 9  Nissan  White   31600.000000    4.0   $9,700.00
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Odometer (KM)'].plot(kind='hist', bins=20, title='Odometer (KM)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Doors'].plot(kind='hist', bins=20, title='Doors')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
# ...

# %%
missing_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White  150043.000000    4.0   $4,000.00
# 1   Honda    Red   87899.000000    4.0   $5,000.00
# 2  Toyota   Blue   32549.000000    NaN   $7,000.00
# 3     BMW  Black   11179.000000    5.0  $22,000.00
# 4  Nissan  White   63657.666667    4.0   $3,500.00
# 5  Toyota  Green   99213.000000    4.0   $4,500.00
# 6   Honda   Blue   45698.000000    4.0         NaN
# 7   Honda   Blue   54738.000000    4.0   $7,000.00
# 8  Toyota    NaN   60000.000000    4.0   $6,250.00
# 9  Nissan  White   31600.000000    4.0   $9,700.00

# %%
missing_data.dropna(inplace=True)

# %%
missing_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White  150043.000000    4.0   $4,000.00
# 1   Honda    Red   87899.000000    4.0   $5,000.00
# 3     BMW  Black   11179.000000    5.0  $22,000.00
# 4  Nissan  White   63657.666667    4.0   $3,500.00
# 5  Toyota  Green   99213.000000    4.0   $4,500.00
# 7   Honda   Blue   54738.000000    4.0   $7,000.00
# 9  Nissan  White   31600.000000    4.0   $9,700.00

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
seats_column = pd.Series([5,5,5,5,5,5])

car_sales["seats"]=seats_column

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales["seats"].fillna(4, inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    4.0
# 7   Honda   Blue          54738      4   $7,000.00    4.0
# 8  Toyota  White          60000      4   $6,250.00    4.0
# 9  Nissan  White          31600      4   $9,700.00    4.0

# %%
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]
car_sales["Fuelpar100Km"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Fuelpar100Km
# 0  Toyota  White         150043      4   $4,000.00    5.0           7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0           9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0           5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0           9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0           8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0           4.7
# 6   Honda   Blue          45698      4   $7,500.00    4.0           7.6
# 7   Honda   Blue          54738      4   $7,000.00    4.0           8.7
# 8  Toyota  White          60000      4   $6,250.00    4.0           3.0
# 9  Nissan  White          31600      4   $9,700.00    4.0           4.5

# %%
car_sales["fuleUsed"]= car_sales["Odometer (KM)"]/100 * car_sales["Fuelpar100Km"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Fuelpar100Km  \
# 0  Toyota  White         150043      4   $4,000.00    5.0           7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0           9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0           5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0           9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0           8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0           4.7
# 6   Honda   Blue          45698      4   $7,500.00    4.0           7.6
# 7   Honda   Blue          54738      4   $7,000.00    4.0           8.7
# 8  Toyota  White          60000      4   $6,250.00    4.0           3.0
# 9  Nissan  White          31600      4   $9,700.00    4.0           4.5
#
#     fuleUsed
# 0  11253.225
# 1   8086.708
# 2   1627.450
# 3   1073.184
# 4  18539.265
# 5   4663.011
# 6   3473.048
# 7   4762.206
# 8   1800.000
# 9   1422.000

# %%
car_sales["NumberOfWheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Fuelpar100Km  \
# 0  Toyota  White         150043      4   $4,000.00    5.0           7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0           9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0           5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0           9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0           8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0           4.7
# 6   Honda   Blue          45698      4   $7,500.00    4.0           7.6
# 7   Honda   Blue          54738      4   $7,000.00    4.0           8.7
# 8  Toyota  White          60000      4   $6,250.00    4.0           3.0
# 9  Nissan  White          31600      4   $9,700.00    4.0           4.5
#
#     fuleUsed  NumberOfWheels
# 0  11253.225               4
# 1   8086.708               4
# 2   1627.450               4
# 3   1073.184               4
# ...

# %%
car_sales["PassRoadSeftey"] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Fuelpar100Km  \
# 0  Toyota  White         150043      4   $4,000.00    5.0           7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0           9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0           5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0           9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0           8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0           4.7
# 6   Honda   Blue          45698      4   $7,500.00    4.0           7.6
# 7   Honda   Blue          54738      4   $7,000.00    4.0           8.7
# 8  Toyota  White          60000      4   $6,250.00    4.0           3.0
# 9  Nissan  White          31600      4   $9,700.00    4.0           4.5
#
#     fuleUsed  NumberOfWheels  PassRoadSeftey
# 0  11253.225               4            True
# 1   8086.708               4            True
# ...

# %%
car_sales["fuleUsed_l"]= car_sales["Odometer (KM)"]/100 * car_sales["Fuelpar100Km"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Fuelpar100Km  \
# 0  Toyota  White         150043      4   $4,000.00    5.0           7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0           9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0           5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0           9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0           8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0           4.7
# 6   Honda   Blue          45698      4   $7,500.00    4.0           7.6
# 7   Honda   Blue          54738      4   $7,000.00    4.0           8.7
# 8  Toyota  White          60000      4   $6,250.00    4.0           3.0
# 9  Nissan  White          31600      4   $9,700.00    4.0           4.5
#
#     fuleUsed  NumberOfWheels  PassRoadSeftey  fuleUsed_l
# 0  11253.225               4            True   11253.225
# 1   8086.708               4            True    8086.708
# ...

# %%
car_sales=car_sales.drop("fuleUsed_l", axis=1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Fuelpar100Km  \
# 0  Toyota  White         150043      4   $4,000.00    5.0           7.5
# 1   Honda    Red          87899      4   $5,000.00    5.0           9.2
# 2  Toyota   Blue          32549      3   $7,000.00    5.0           5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0           9.6
# 4  Nissan  White         213095      4   $3,500.00    5.0           8.7
# 5  Toyota  Green          99213      4   $4,500.00    5.0           4.7
# 6   Honda   Blue          45698      4   $7,500.00    4.0           7.6
# 7   Honda   Blue          54738      4   $7,000.00    4.0           8.7
# 8  Toyota  White          60000      4   $6,250.00    4.0           3.0
# 9  Nissan  White          31600      4   $9,700.00    4.0           4.5
#
#     fuleUsed  NumberOfWheels  PassRoadSeftey
# 0  11253.225               4            True
# 1   8086.708               4            True
# ...

# %%
car_sales.sample(frac=0.4)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  seats  Fuelpar100Km  \
# 8  Toyota  White          60000      4  $6,250.00    4.0           3.0
# 6   Honda   Blue          45698      4  $7,500.00    4.0           7.6
# 1   Honda    Red          87899      4  $5,000.00    5.0           9.2
# 4  Nissan  White         213095      4  $3,500.00    5.0           8.7
#
#     fuleUsed  NumberOfWheels  PassRoadSeftey
# 8   1800.000               4            True
# 6   3473.048               4            True
# 1   8086.708               4            True
# 4  18539.265               4            True

# %%
car_sales_suffled=car_sales.sample(frac=1)
car_sales_suffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Fuelpar100Km  \
# 4  Nissan  White         213095      4   $3,500.00    5.0           8.7
# 3     BMW  Black          11179      5  $22,000.00    5.0           9.6
# 9  Nissan  White          31600      4   $9,700.00    4.0           4.5
# 6   Honda   Blue          45698      4   $7,500.00    4.0           7.6
# 5  Toyota  Green          99213      4   $4,500.00    5.0           4.7
# 7   Honda   Blue          54738      4   $7,000.00    4.0           8.7
# 1   Honda    Red          87899      4   $5,000.00    5.0           9.2
# 0  Toyota  White         150043      4   $4,000.00    5.0           7.5
# 2  Toyota   Blue          32549      3   $7,000.00    5.0           5.0
# 8  Toyota  White          60000      4   $6,250.00    4.0           3.0
#
#     fuleUsed  NumberOfWheels  PassRoadSeftey
# 4  18539.265               4            True
# 3   1073.184               4            True
# ...

# %%
car_sales_suffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors       Price  seats  \
# 0      8  Toyota  White          60000      4   $6,250.00    4.0
# 1      3     BMW  Black          11179      5  $22,000.00    5.0
# 2      4  Nissan  White         213095      4   $3,500.00    5.0
# 3      2  Toyota   Blue          32549      3   $7,000.00    5.0
# 4      5  Toyota  Green          99213      4   $4,500.00    5.0
# 5      7   Honda   Blue          54738      4   $7,000.00    4.0
# 6      1   Honda    Red          87899      4   $5,000.00    5.0
# 7      9  Nissan  White          31600      4   $9,700.00    4.0
# 8      0  Toyota  White         150043      4   $4,000.00    5.0
# 9      6   Honda   Blue          45698      4   $7,500.00    4.0
#
#    Fuelpar100Km   fuleUsed  NumberOfWheels  PassRoadSeftey
# 0           3.0   1800.000               4            True
# 1           9.6   1073.184               4            True
# 2           8.7  18539.265               4            True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x:x / 1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  seats  Fuelpar100Km  \
# 0  Toyota  White      93776.875      4   $4,000.00    5.0           7.5
# 1   Honda    Red      54936.875      4   $5,000.00    5.0           9.2
# 2  Toyota   Blue      20343.125      3   $7,000.00    5.0           5.0
# 3     BMW  Black       6986.875      5  $22,000.00    5.0           9.6
# 4  Nissan  White     133184.375      4   $3,500.00    5.0           8.7
# 5  Toyota  Green      62008.125      4   $4,500.00    5.0           4.7
# 6   Honda   Blue      28561.250      4   $7,500.00    4.0           7.6
# 7   Honda   Blue      34211.250      4   $7,000.00    4.0           8.7
# 8  Toyota  White      37500.000      4   $6,250.00    4.0           3.0
# 9  Nissan  White      19750.000      4   $9,700.00    4.0           4.5
#
#     fuleUsed  NumberOfWheels  PassRoadSeftey
# 0  11253.225               4            True
# 1   8086.708               4            True
# ...
